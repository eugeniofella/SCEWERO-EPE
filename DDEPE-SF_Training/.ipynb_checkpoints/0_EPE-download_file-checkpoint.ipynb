# %%
# Import modules
import gdown
import zipfile

# %% [markdown]
# # Step-1 Download files for precipitation

# %%
url = "https://drive.google.com/file/d/1PerAjyLh_7PB2RjumMrjmmoaIO3aFBzb/view?usp=share_link"
output = "../DATA/data_bundle.zip"
gdown.download(url, output, quiet=False)

with zipfile.ZipFile(output, 'r') as zip_ref:
    zip_ref.extractall("../DATA/")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1PerAjyLh_7PB2RjumMrjmmoaIO3aFBzb
# From (redirected): https://drive.google.com/uc?id=1PerAjyLh_7PB2RjumMrjmmoaIO3aFBzb&confirm=t&uuid=1e6d766e-9835-462c-bf3f-09f8b5f34ecf
# To: /home/eugenio/Scrivania/SCEWERO/DDEPE-SF/DATA/data_bundle.zip
# 100%|██████████████████████████████████████| 52.8M/52.8M [00:01<00:00, 46.8MB/s]
