# %%
# Import libraries
import gdown
import zipfile

# %% [markdown]
# # Step-1 Download files for precipitation

# %%
url = "https://drive.google.com/file/d/1rJO3PQnn4yuqtir-TqKScopxZJcPmqrI/view?usp=sharing"
output = "../data_epe.zip"
gdown.download(url, output, quiet=False)

with zipfile.ZipFile(output, 'r') as zip_ref:
    zip_ref.extractall("../")
